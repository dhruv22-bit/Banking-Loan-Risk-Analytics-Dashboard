# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\chanc\Downloads\Loan_data.csv")
df.head()
# Out:
#   Customer_ID  Age  Gender Marital_Status     Education Employment_Type  \
# 0   CUST00001   41    Male        Married  Non-Graduate        Salaried
# 1   CUST00002   53    Male        Married      Graduate        Salaried
# 2   CUST00003   58    Male        Married      Graduate        Salaried
# 3   CUST00004   35  Female         Single      Graduate   Self-Employed
# 4   CUST00005   35  Female        Married  Non-Graduate        Salaried
#
#    Annual_Income  Loan_Amount  Loan_Term  Credit_Score Existing_Loan  \
# 0        1878050       818747         36           552            No
# 1        1021106       274695        240           798           Yes
# 2        1415502       934315         36           720           Yes
# 3        1819135      1394476         12           556            No
# 4        1060120      1151844         24           521           Yes
#
#   Property_Area       State Loan_Purpose Loan_Status Default_Status  \
# 0     Semiurban       Delhi         Home    Approved             No
# 1         Urban  Tamil Nadu    Education    Approved             No
# 2         Rural      Punjab          Car    Approved             No
# 3         Rural       Delhi         Home    Rejected            Yes
# 4         Rural   Rajasthan    Education    Rejected             No
#
#    Interest_Rate        EMI
# 0          14.42   32581.58
# 1          10.62    3575.61
# 2           7.92   32119.67
# 3           7.55  124979.91
# 4           7.46   55154.13

# %% [markdown]
# Data Understanding

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer_ID      1000 non-null   str
#  1   Age              1000 non-null   int64
#  2   Gender           1000 non-null   str
#  3   Marital_Status   1000 non-null   str
#  4   Education        1000 non-null   str
#  5   Employment_Type  1000 non-null   str
#  6   Annual_Income    1000 non-null   int64
#  7   Loan_Amount      1000 non-null   int64
#  8   Loan_Term        1000 non-null   int64
#  9   Credit_Score     1000 non-null   int64
#  10  Existing_Loan    1000 non-null   str
#  11  Property_Area    1000 non-null   str
#  12  State            1000 non-null   str
#  13  Loan_Purpose     1000 non-null   str
#  14  Loan_Status      1000 non-null   str
#  15  Default_Status   1000 non-null   str
#  16  Interest_Rate    1000 non-null   float64
#  17  EMI              1000 non-null   float64
# dtypes: float64(2), int64(5), str(11)
# memory usage: 140.8 KB
# Customer_ID        0
# Age                0
# Gender             0
# Marital_Status     0
# Education          0
# Employment_Type    0
# Annual_Income      0
# Loan_Amount        0
# Loan_Term          0
# Credit_Score       0
# Existing_Loan      0
# Property_Area      0
# State              0
# Loan_Purpose       0
# Loan_Status        0
# Default_Status     0
# Interest_Rate      0
# EMI                0
# dtype: int64

# %% [markdown]
# Loan Status Distribution

# %%
sns.set_style("darkgrid")
sns.countplot(data = df , x = "Loan_Status")
plt.show()

# %% [markdown]
# Default Status

# %%
sns.countplot(data = df , x = "Default_Status")
plt.show()

# %% [markdown]
# Credit Score Distribution

# %%
sns.histplot(df["Credit_Score"],kde =  True)
plt.show()

# %% [markdown]
# Income vs Loan Amount

# %%
sns.scatterplot(data = df , x = "Annual_Income" , y = "Loan_Amount", hue = "Default_Status")
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
numeric_df = df.select_dtypes(include='number')

sns.heatmap(
    numeric_df.corr(),
    annot=True
)
plt.show()
